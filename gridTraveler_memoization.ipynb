# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroFrey/Dynamic-Programming/blob/main/gridTraveler_memoization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %%time
def grid(row,column,memo = {}):
  key = str(row) + "," + str(column)
  if key in memo:
    return memo[key]

  elif row == 0:
    return 0
  elif column == 0:
    return 0
  elif row and column == 1:
    return 1
  else:
    memo[key]= grid(row-1,column)+grid(row,column-1)
    return memo[key]

# print(grid(0,0))
# print(grid(1,0))
# print(grid(0,1))
# print(grid(1,1))
# print(grid(1,2))
# print(grid(3,2))
#print(grid(3,3))
print(grid(18,18))
# Out:
# 2333606220
# CPU times: user 1.64 ms, sys: 0 ns, total: 1.64 ms
# Wall time: 1.72 ms

# %%
# %%time
def grid(row,column,memo = {}):
  key = str(row) + "," + str(column)
  if key in memo:
    return memo[key]

  elif row == 0:
    return 0
  elif column == 0:
    return 0
  elif row and column == 1:
    return 1
  else:
    memo[key]= grid(row-1,column,memo)+grid(row,column-1,memo)
    return memo[key]

# print(grid(0,0))
# print(grid(1,0))
# print(grid(0,1))
# print(grid(1,1))
# print(grid(1,2))
# print(grid(3,2))
#print(grid(3,3))
print(grid(18,18))
# Out:
# 2333606220
# CPU times: user 1.08 ms, sys: 0 ns, total: 1.08 ms
# Wall time: 1.09 ms
